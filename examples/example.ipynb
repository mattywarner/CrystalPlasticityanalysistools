# %%
import CPanalysistools
# Out:
# /opt/homebrew/Cellar/micromamba/2.0.8/envs/pymc-env/lib/python3.13/site-packages/CPanalysistools/_CPanalysistools.py:421: SyntaxWarning: invalid escape sequence '\s'
#   ax.set_ylabel('True stress, $\sigma_{xx}$ (MPa)', fontsize=label_fontsize)
# /opt/homebrew/Cellar/micromamba/2.0.8/envs/pymc-env/lib/python3.13/site-packages/CPanalysistools/_CPanalysistools.py:422: SyntaxWarning: invalid escape sequence '\e'
#   ax.set_xlabel('True strain, $\epsilon_{xx}$', fontsize=label_fontsize)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import CPanalysistools
#
# File /opt/homebrew/Cellar/micromamba/2.0.8/envs/pymc-env/lib/python3.13/site-packages/CPanalysistools/__init__.py:1
# ----> 1 from ._CPanalysistools import *
#
# File /opt/homebrew/Cellar/micromamba/2.0.8/envs/pymc-env/lib/python3.13/site-packages/CPanalysistools/_CPanalysistools.py:11
# ...
